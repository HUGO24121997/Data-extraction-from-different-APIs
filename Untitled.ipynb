# %%
import requests

params = {
  'access_key': 'eef27b87fa9fb9094783c8769cb71d83'
}

api_result = requests.get('http://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Your current subscription plan does not support this API function.'}}

# %%
import requests

url1=""
url2="https://api.covidtracking.com/v1/us/daily.json"


reponse1 = requests.get(url1)
reponse2 = requests.get(url2)
print(reponse)

import json
json_res1 = reponse1.json()
json_res2 = reponse2.json()


print(type(json_res1))
print(type(json_res2))
# Out:
# <Response [200]>
# <class 'dict'>
# <class 'list'>

# %%
begin = 1577833200 #Code Unix pour le 01-01-2020 00:00:00
end = 1577840400 #Code Unix pour le 01-01-2020 02:00:00
url_vols="https://opensky-network.org/api/flights/all?begin="+str(begin)+"&end="+str(end)
reponse_vols = requests.get(url_vols)
reponse_vols_json = reponse_vols.json()
print(type(reponse_vols_json))
print(reponse_vols_json)
# Out:
# <class 'list'>
# ...

# %%
len(reponse_vols_json)
# Out:
# 2830

# %%
x = 1577833200 - 1577840400
x
# Out:
# -7200

# %%
begin = 1577833200 #Code Unix pour le 01-01-2020 00:00:00
end = 1577840400 #Code Unix pour le 01-01-2020 02:00:00

total_jour = 0
total_par_jour = []


jour_par_mois = [31,29,31,30,31,30,31,31,30,31,30,31]
mois = ["Janvier", "Fevrier", "Mars", "Avril", "Mai", "Juin", "Juilliet", "Aout", "Septembre", "Octobre", "Novembre", "Decembre"]

total_mois = 0
total_par_mois = {}
total_annee = 0


for k in range(0,12) :
    for j in range(0,jour_par_mois[k]):           
        for i in range(0,12) :
            url_vols="https://opensky-network.org/api/flights/all?begin="+str(begin)+"&end="+str(end)
            reponse_vols = requests.get(url_vols)
            reponse_vols_json = reponse_vols.json()
            total_jour += len(reponse_vols_json)
            del reponse_vols
            del reponse_vols_json
            begin = end
            end += 7200
        total_par_jour.append(total_jour)
        total_mois += total_jour
        total_jour = 0
    total_par_mois[mois[k]] = jours
    total_annee += total_mois
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4488/2645176346.py in <module>
#      19             url_vols="https://opensky-network.org/api/flights/all?begin="+str(begin)+"&end="+str(end)
#      20             reponse_vols = requests.get(url_vols)
# ---> 21             reponse_vols_json = reponse_vols.json()
#      22             total_jour += len(reponse_vols_json)
#      23             del reponse_vols
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
for i in range(0,12) :
    url_vols="https://opensky-network.org/api/flights/all?begin="+str(begin)+"&end="+str(end)
    reponse_vols = requests.get(url_vols)
    reponse_vols_json = reponse_vols.json()
    j += len(reponse_vols_json)
    begin = end + 1
    end += 7201

# %%
j
# Out:
# 67139

# %% [markdown]
# On voit ici que l’on a reçu une réponse de code 200, ce qui signifie que la requête s’est déroulée correctement.

# %%
json_res11
# Out:
# {'time': 1642713169,
#  'states': [['4b1814',
#    'SWR98R  ',
#    'Switzerland',
#    1642713167,
#    1642713167,
#    8.5564,
#    47.4576,
#    None,
#    True,
#    47.33,
#    275.62,
#    None,
#    None,
#    None,
#    '1000',
#    False,
#    0],
#   ['a808c4',
#    'PDT6165 ',
#    'United States',
#    1642713168,
#    1642713168,
#    -84.6958,
#    33.1493,
#    10058.4,
#    False,
#    253.55,
#    56.08,
#    -0.65,
#    None,
#    10248.9,
#    '2540',
#    False,
#    0],
#   ['ab1644',
#    'UAL1870 ',
#    'United States',
#    1642713168,
#    1642713168,
#    -92.2001,
#    33.5454,
#    8534.4,
#    False,
#    186.31,
#    231.39,
#    0,
#    None,
#    8602.98,
#    '1167',
#    False,
#    0],
#   ['a6fe0f',
#    'N55LC   ',
#    'United States',
#    1642713072,
#    1642713072,
#    -80.7769,
#    34.9485,
#    1584.96,
#    False,
#    108.47,
#    257.68,
#    -5.2,
#    None,
#    1600.2,
#    None,
#    False,
#    0],
#   ['c822af',
# ...

# %%
import pandas as pd
df1 = pd.DataFrame(api_response['data'])

df1
# Out:
#    flight_date flight_status  \
# 0   2022-01-21     scheduled
# 1   2022-01-21        active
# 2   2022-01-21     scheduled
# 3   2022-01-21     scheduled
# 4   2022-01-21     scheduled
# ..         ...           ...
# 95  2022-01-21     scheduled
# 96  2022-01-21     scheduled
# 97  2022-01-21     scheduled
# 98  2022-01-21     scheduled
# 99  2022-01-21     scheduled
#
#                                             departure  \
# 0   {'airport': 'Tan Son Nhat International', 'tim...
# 1   {'airport': 'Hong Kong International', 'timezo...
# 2   {'airport': 'Christchurch International', 'tim...
# 3   {'airport': 'Jazan', 'timezone': 'Asia/Riyadh'...
# 4   {'airport': 'Kingsford Smith', 'timezone': 'Au...
# ..                                                ...
# 95  {'airport': 'Taiyuan', 'timezone': 'Asia/Shang...
# 96  {'airport': 'Taiyuan', 'timezone': 'Asia/Shang...
# 97  {'airport': 'Taiyuan', 'timezone': 'Asia/Shang...
# 98  {'airport': 'Taiyuan', 'timezone': 'Asia/Shang...
# ...

# %%
df.head()
# Out:
#        0         1              2             3           4         5   \
# 0  4b1814  SWR97L      Switzerland  1.642703e+09  1642703384   11.9300
# 1  a808c5  CTF617    United States  1.642703e+09  1642703384 -105.2135
# 2  e49406  GLO2177          Brazil           NaN  1642703381       NaN
# 3  a808c4  PDT6165   United States  1.642703e+09  1642703384  -81.6480
# 4  ac96b4  N910AJ    United States  1.642703e+09  1642703383  -80.5558
#
#         6         7      8       9       10    11    12        13    14  \
# 0  50.8465  10393.68  False  190.44   40.62 -3.90  None  10157.46  2611
# 1  38.9082   7924.80  False  230.99  206.74  0.00  None   7917.18  2224
# 2      NaN       NaN  False  233.40  176.84  0.00  None       NaN  None
# 3  34.9813   5052.06  False  156.20  247.74  7.80  None   5090.16  2071
# 4  26.2347   3169.92  False  118.71  236.31 -0.33  None   3276.60  None
#
#       15  16  17
# 0  False   0   0
# 1  False   0   0
# 2  False   0   0
# 3  False   0   1
# ...

# %%
df.drop(12, 1, inplace=True)
# Out:
# C:\Users\Administrateur\AppData\Local\Temp/ipykernel_4488/1650882489.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(12, 1, inplace=True)

# %%
    keys = ["icao24", "callsign", "origin_country", "time_position",
            "last_contact", "longitude", "latitude", "baro_altitude", "on_ground",
            "velocity", "heading", "vertical_rate", "sensors",
            "geo_altitude", "squawk", "spi", "position_source"]
    
    df.set_axis(keys, axis=1)
# Out:
#       icao24  callsign origin_country  time_position  last_contact  longitude  \
# 0     4b1814  SWR97L      Switzerland   1.642705e+09    1642704927    13.5179
# 1     a808c5  CTF617    United States   1.642705e+09    1642704926  -108.1653
# 2     e49406  GLO2177          Brazil   1.642705e+09    1642704799   -43.2930
# 3     ac96b6  N910AL    United States   1.642705e+09    1642704927   -81.3998
# 4     a808c4  PDT6165   United States   1.642705e+09    1642704927   -83.9878
# ...      ...       ...            ...            ...           ...        ...
# 6912  a00425  N10UH     United States   1.642705e+09    1642704927   -94.3517
# 6913  aceced  N93184    United States   1.642705e+09    1642704873   -80.3364
# 6914  a54e7b  N441BP    United States   1.642705e+09    1642704927   -86.7269
# 6915  a66e64  GAJ513    United States   1.642705e+09    1642704920   -90.7025
# 6916  c00734  WJA2766          Canada   1.642705e+09    1642704721   -69.0057
#
# ...

# %%
json_res2
# Out:
# [{'date': 20210307,
#   'states': 56,
#   'positive': 28756489,
#   'negative': 74582825,
#   'pending': 11808,
#   'hospitalizedCurrently': 40199,
#   'hospitalizedCumulative': 776361,
#   'inIcuCurrently': 8134,
#   'inIcuCumulative': 45475,
#   'onVentilatorCurrently': 2802,
#   'onVentilatorCumulative': 4281,
#   'dateChecked': '2021-03-07T24:00:00Z',
#   'death': 515151,
#   'hospitalized': 776361,
#   'totalTestResults': 363825123,
#   'lastModified': '2021-03-07T24:00:00Z',
#   'recovered': None,
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 842,
#   'hospitalizedIncrease': 726,
#   'negativeIncrease': 131835,
#   'positiveIncrease': 41835,
#   'totalTestResultsIncrease': 1170059,
#   'hash': 'a80d0063822e251249fd9a44730c49cb23defd83'},
#  {'date': 20210306,
#   'states': 56,
#   'positive': 28714654,
#   'negative': 74450990,
#   'pending': 11783,
#   'hospitalizedCurrently': 41401,
#   'hospitalizedCumulative': 775635,
#   'inIcuCurrently': 8409,
# ...

# %%
import pandas as pd
df = pd.DataFrame(json_res2)

df
# Out:
#          date  states    positive    negative  pending  hospitalizedCurrently  \
# 0    20210307      56  28756489.0  74582825.0  11808.0                40199.0
# 1    20210306      56  28714654.0  74450990.0  11783.0                41401.0
# 2    20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3    20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4    20210303      56  28520365.0  73857281.0  11778.0                45462.0
# ..        ...     ...         ...         ...      ...                    ...
# 415  20200117       1         0.0         NaN      NaN                    NaN
# 416  20200116       1         0.0         NaN      NaN                    NaN
# 417  20200115       1         0.0         NaN      NaN                    NaN
# 418  20200114       1         0.0         NaN      NaN                    NaN
# 419  20200113       1         NaN         NaN      NaN                    NaN
#
# ...

# %%
import sqlite3
conn1 = sqlite3.connect("json_res.db") 

df.to_sql("sun",conn1)

# %%
import sqlite3
conn = sqlite3.connect("json_res.db") 

df.to_sql("sun",conn)
